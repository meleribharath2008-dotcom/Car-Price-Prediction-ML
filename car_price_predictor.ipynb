# %% [markdown]
# importing dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# %% [markdown]
# data collection and preprocess

# %%
car_dataset=pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

# %%
car_dataset.head()
# Out:
#                        name  year  ...  transmission         owner
# 0             Maruti 800 AC  2007  ...        Manual   First Owner
# 1  Maruti Wagon R LXI Minor  2007  ...        Manual   First Owner
# 2      Hyundai Verna 1.6 SX  2012  ...        Manual   First Owner
# 3    Datsun RediGO T Option  2017  ...        Manual   First Owner
# 4     Honda Amaze VX i-DTEC  2014  ...        Manual  Second Owner
#
# [5 rows x 8 columns]

# %%
car_dataset.shape
# Out:
# (4340, 8)

# %%
car_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
car_dataset.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
print(car_dataset.fuel.value_counts())
print(car_dataset.seller_type.value_counts())
print(car_dataset.transmission.value_counts())
print(car_dataset.owner.value_counts())
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %% [markdown]
# encoding categorial data

# %%
car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)
car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)
car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)
# Out:
# /tmp/ipykernel_2847/674937336.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)

# %%
car_dataset.head()
# Out:
#                        name  year  ...  transmission  owner
# 0             Maruti 800 AC  2007  ...             0      0
# 1  Maruti Wagon R LXI Minor  2007  ...             0      0
# 2      Hyundai Verna 1.6 SX  2012  ...             0      0
# 3    Datsun RediGO T Option  2017  ...             0      0
# 4     Honda Amaze VX i-DTEC  2014  ...             0      1
#
# [5 rows x 8 columns]

# %%
car_dataset.replace({'owner':{'First Owner':0,'Second Owner':1,'Third Owner':2,'Fourth & Above Owner':3,'Test Drive Car':4}},inplace=True)

# %%
car_dataset.head()
# Out:
#                        name  year  ...  transmission  owner
# 0             Maruti 800 AC  2007  ...             0      0
# 1  Maruti Wagon R LXI Minor  2007  ...             0      0
# 2      Hyundai Verna 1.6 SX  2012  ...             0      0
# 3    Datsun RediGO T Option  2017  ...             0      0
# 4     Honda Amaze VX i-DTEC  2014  ...             0      1
#
# [5 rows x 8 columns]

# %% [markdown]
# spliting data and target

# %%
X =car_dataset.drop(['name','selling_price'],axis=1)
Y =car_dataset['selling_price']

# %%
print(X)
# Out:
#       year  km_driven  fuel  seller_type  transmission  owner
# 0     2007      70000     0            1             0      0
# 1     2007      50000     0            1             0      0
# 2     2012     100000     1            1             0      0
# 3     2017      46000     0            1             0      0
# 4     2014     141000     1            1             0      1
# ...    ...        ...   ...          ...           ...    ...
# 4335  2014      80000     1            1             0      1
# 4336  2014      80000     1            1             0      1
# 4337  2009      83000     0            1             0      1
# 4338  2016      90000     1            1             0      0
# 4339  2016      40000     0            1             0      0
#
# [4340 rows x 6 columns]

# %%
print(Y)
# Out:
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4340, dtype: int64

# %% [markdown]
# spliting training and testing data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %% [markdown]
# model training

# %% [markdown]
# linear regression model

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# model evaluation

# %%
training_pred=lr.predict(X_train)

# %% [markdown]
# r squared error

# %%
error=metrics.r2_score(Y_train,training_pred)

# %%
print(error)
# Out:
# 0.4267032363113096

# %% [markdown]
# visualise the actual price and predictions

# %%
plt.scatter(Y_train,training_pred)
plt.xlabel("ACTUAL PRICE")
plt.ylabel("PREDICTED PRICE")
plt.title("ACTUAL PRICE VS PREDICTED PRICE")
plt.show()

# %% [markdown]
# testing data check

# %%
test_pred=lr.predict(X_test)

# %%
error1=metrics.r2_score(Y_test,test_pred)

# %%
print(error1)
# Out:
# 0.46897548907629794

# %%
plt.scatter(Y_test,test_pred)
plt.xlabel("ACTUAL PRICE")
plt.ylabel("PREDICTED PRICE")
plt.title("ACTUAL PRICE VS PREDICTED PRICE")
plt.show()

# %% [markdown]
# lasso regression

# %%
lar=Lasso()

# %%
lar.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
model evaluation

# %%
training_data_pred=lar.predict(X_train)

# %%
error2=metrics.r2_score(Y_train,training_data_pred)

# %%
print(error2)
# Out:
# 0.42670323625744433

# %%
plt.scatter(Y_train,training_data_pred)
plt.xlabel("ACTUAL PRICE")
plt.ylabel("PREDICTED PRICE")
plt.title("ACTUAL PRICE VS PREDICTED PRICE")
plt.show()

# %%
testing_data_pred=lar.predict(X_test)

# %%
error3=metrics.r2_score(Y_test,testing_data_pred)

# %%
print(error3)
# Out:
# 0.46897506154011537

# %%
plt.scatter(Y_test,testing_data_pred)
plt.xlabel("ACTUAL PRICE")
plt.ylabel("PREDICTED PRICE")
plt.title("ACTUAL PRICE VS PREDICTED PRICE")
plt.show()
